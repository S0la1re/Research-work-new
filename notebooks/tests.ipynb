# %% [markdown]
# # Tests
# ## Import libraries

# %%
import os
import sys
import openai
import pandas as pd
from dotenv import load_dotenv


src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# %load_ext autoreload
# %autoreload 2

from jobs_tools import tests_helpers, chat_gpt


load_dotenv()
client_async = openai.AsyncOpenAI()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv("../data/csv/df_translated.csv")
df.head()
# Out:
#   Location  Region  EU Member  Schengen Agreement Google Domain Type  \
# 0  Austria  Europe       True                True              local
# 1  Austria  Europe       True                True            default
# 2  Austria  Europe       True                True            default
# 3  Austria  Europe       True                True            default
# 4  Austria  Europe       True                True            default
#
#   Google Domain Used                                          Job Title  \
# 0          google.at  Sandbox Innovation Sdn. Bhd. | Senior Mobile A...
# 1         google.com                       Mobile Application Developer
# 2         google.com  Android Developer – Kotlin (Austria based, Hyb...
# 3         google.com                            Android & iOS Developer
# 4         google.com                          iOS Developer Up3 (f/m/d)
#
#            Company Name     Job Location  \
# 0       Tideri Jobbörse          Austria
# 1        Pearson Carter          Austria
# 2  Bitcoin Devs Company  Vienna, Austria
# 3         ventopay gmbh          Austria
# 4       Drei Österreich  Vienna, Austria
#
#                            Apply Options  \
# 0  Trabajo.org - Stellenangebote, Arbeit
# 1  Trabajo.org - Stellenangebote, Arbeit
# 2                                  Jobs3
# 3                 StudySmarter - Talents
# 4       MyAbility.jobs, Drei., Jobted.at
#
#                                      Job Description Work from home Salary  \
# 0  We are a dynamic FinTech company headquartered...            NaN    NaN
# 1  Lead Mobile Developer | Hyper Growth Startup |...            NaN    NaN
# 2  Overview:\r\nThe Android Developer – Kotlin po...            NaN    NaN
# 3  Was sind deine Aufgaben?\r\n• Du gestaltest at...            NaN    NaN
# 4  Do you want to push the frontier of digital se...            NaN    NaN
#
#   Schedule type       Qualifications  \
# 0     Full-time                  NaN
# 1     Full-time  No degree mentioned
# 2    Contractor  No degree mentioned
# 3     Full-time  No degree mentioned
# 4     Full-time  No degree mentioned
#
#                                               Job ID              Search Date  \
# 0  eyJqb2JfdGl0bGUiOiJTYW5kYm94IElubm92YXRpb24gU2...  2025-01-13 12:33:21 UTC
# 1  eyJqb2JfdGl0bGUiOiJNb2JpbGUgQXBwbGljYXRpb24gRG...  2025-01-13 12:08:51 UTC
# 2  eyJqb2JfdGl0bGUiOiJBbmRyb2lkIERldmVsb3BlciDigJ...  2025-01-13 12:08:48 UTC
# 3  eyJqb2JfdGl0bGUiOiJBbmRyb2lkIFx1MDAyNiBpT1MgRG...  2025-01-13 12:20:43 UTC
# 4  eyJqb2JfdGl0bGUiOiJpT1MgRGV2ZWxvcGVyIFVwMyAoZi...  2025-01-13 12:20:39 UTC
#
#         Search Query Language  \
# 0      iOS developer       en
# 1  Android developer       en
# 2  Android developer       en
# 3      iOS developer       de
# 4      iOS developer       en
#
#                              Job Description English
# 0  We are a dynamic FinTech company headquartered...
# 1  Lead Mobile Developer | Hyper Growth Startup |...
# 2  Overview:\r\nThe Android Developer – Kotlin po...
# 3  **What are your tasks?**  \r\n- You design att...
# 4  Do you want to push the frontier of digital se...

# %% [markdown]
# ## Split job descriptions into structured sections
# ### Columns into text

# %%
sample = df.sample(n=30, random_state=42)
tests_helpers.column_to_txt(column='Job Description English', output="../data/ground_truth/job_descriptions_sample.txt", df=sample)

# %% [markdown]
# ### Load ground truth into DataFrame

# %%
test = tests_helpers.txt_to_column(txt_path="../data/ground_truth/job_descriptions_ground_truth.txt", df=sample)
test.head()
# Out:
#             Location            Region  EU Member  Schengen Agreement  \
# 1575          Poland            Europe       True                True
# 324           Canada  Northern America      False               False
# 1491     Netherlands            Europe       True                True
# 1815         Romania            Europe       True                True
# 2174  United Kingdom            Europe      False               False
#
#      Google Domain Type Google Domain Used  \
# 1575            default         google.com
# 324             default         google.com
# 1491            default         google.com
# 1815            default         google.com
# 2174            default         google.com
#
#                                   Job Title Company Name  \
# 1575                      Android Developer   Connectis_
# 324                  iOS Developer (Remote)       McAfee
# 1491                          IOS developer    StarApple
# 1815         Android Developer / CTS Expert       Luxoft
# 2174  Embedded Software Developer (Android)    Integrity
#
#                     Job Location             Apply Options  ...  \
# 1575              Kórnik, Poland               HitPraca.pl  ...
# 324         Waterloo, ON, Canada                     Blind  ...
# 1491      Eindhoven, Netherlands             Werkzoeken.nl  ...
# 1815                     Romania  Indeed, Jooble, LinkedIn  ...
# 2174  Chesterton, United Kingdom                 SitePoint  ...
#
#      Work from home Salary Schedule type       Qualifications  \
# 1575            NaN    NaN     Full-time  No degree mentioned
# 324             NaN    NaN     Full-time  No degree mentioned
# 1491            NaN    NaN     Full-time  No degree mentioned
# 1815            NaN    NaN     Full-time  No degree mentioned
# 2174            NaN    NaN     Full-time                  NaN
#
#                                                  Job ID  \
# 1575  eyJqb2JfdGl0bGUiOiJBbmRyb2lkIERldmVsb3BlciIsIm...
# 324   eyJqb2JfdGl0bGUiOiJpT1MgRGV2ZWxvcGVyIChSZW1vdG...
# 1491  eyJqb2JfdGl0bGUiOiJJT1MgZGV2ZWxvcGVyIiwiY29tcG...
# 1815  eyJqb2JfdGl0bGUiOiJBbmRyb2lkIERldmVsb3BlciAvIE...
# 2174  eyJqb2JfdGl0bGUiOiJFbWJlZGRlZCBTb2Z0d2FyZSBEZX...
#
#                   Search Date       Search Query Language  \
# 1575  2025-01-13 12:11:12 UTC  Android developer       pl
# 324   2025-01-13 12:21:02 UTC      iOS developer       en
# 1491  2025-01-13 12:22:59 UTC      iOS developer       nl
# 1815  2025-01-13 12:11:28 UTC  Android developer       en
# 2174  2025-01-13 12:12:03 UTC  Android developer       en
#
#                                 Job Description English  \
# 1575  **Android Developer**  \r\n**Location:** Pozna...
# 324   Role OverviewMcAfee is searching for an interm...
# 1491  **Organization & Department**\r\n\r\nAre you i...
# 1815  Remote Romania, Romania\r\n\r\nAndroid\r\n\r\n...
# 2174  If you have experience developing embedded rea...
#
#                                            Ground Truth
# 1575  1. Platform: Android\n2. Salary: Not mentioned...
# 324   1. Platform: iOS\n2. Salary: Not mentioned\n3....
# 1491  1. Platform: iOS\n2. Salary: €3,200 to €5,000\...
# 1815  1. Platform: Android\n2. Salary: Not mentioned...
# 2174  1. Platform: Android\n2. Salary: £40-50K plus ...
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Split ground truth into sections

# %%
test["Platform_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"1\. Platform"))
test["Salary_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"2\. Salary"))
test["Requirements_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"3\. Requirements"))
test["Nice to have_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"4\. Nice to have"))
test["Responsibilities_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"5\. Responsibilities"))
test["Benefits_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"6\. Benefits"))

test.head()
# Out:
#             Location            Region  EU Member  Schengen Agreement  \
# 1575          Poland            Europe       True                True
# 324           Canada  Northern America      False               False
# 1491     Netherlands            Europe       True                True
# 1815         Romania            Europe       True                True
# 2174  United Kingdom            Europe      False               False
#
#      Google Domain Type Google Domain Used  \
# 1575            default         google.com
# 324             default         google.com
# 1491            default         google.com
# 1815            default         google.com
# 2174            default         google.com
#
#                                   Job Title Company Name  \
# 1575                      Android Developer   Connectis_
# 324                  iOS Developer (Remote)       McAfee
# 1491                          IOS developer    StarApple
# 1815         Android Developer / CTS Expert       Luxoft
# 2174  Embedded Software Developer (Android)    Integrity
#
#                     Job Location             Apply Options  ...  \
# 1575              Kórnik, Poland               HitPraca.pl  ...
# 324         Waterloo, ON, Canada                     Blind  ...
# 1491      Eindhoven, Netherlands             Werkzoeken.nl  ...
# 1815                     Romania  Indeed, Jooble, LinkedIn  ...
# 2174  Chesterton, United Kingdom                 SitePoint  ...
#
#            Search Query Language  \
# 1575  Android developer       pl
# 324       iOS developer       en
# 1491      iOS developer       nl
# 1815  Android developer       en
# 2174  Android developer       en
#
#                                 Job Description English  \
# 1575  **Android Developer**  \r\n**Location:** Pozna...
# 324   Role OverviewMcAfee is searching for an interm...
# 1491  **Organization & Department**\r\n\r\nAre you i...
# 1815  Remote Romania, Romania\r\n\r\nAndroid\r\n\r\n...
# 2174  If you have experience developing embedded rea...
#
#                                            Ground Truth Platform_GT  \
# 1575  1. Platform: Android\n2. Salary: Not mentioned...     Android
# 324   1. Platform: iOS\n2. Salary: Not mentioned\n3....         iOS
# 1491  1. Platform: iOS\n2. Salary: €3,200 to €5,000\...         iOS
# 1815  1. Platform: Android\n2. Salary: Not mentioned...     Android
# 2174  1. Platform: Android\n2. Salary: £40-50K plus ...     Android
#
#                   Salary_GT  \
# 1575          Not mentioned
# 324           Not mentioned
# 1491       €3,200 to €5,000
# 1815          Not mentioned
# 2174  £40-50K plus benefits
#
#                                         Requirements_GT  \
# 1575  - Minimum 3 years of commercial experience as ...
# 324   - You can develop iOS applications at an inter...
# 1491  - 3 years of work experience with Swift\n  - B...
# 1815  - Deep expertise in Google CTS tests\n  - Stro...
# 2174  - Degree in relevant subject\n  - Embedded rea...
#
#                                         Nice to have_GT  \
# 1575  - Familiarity with technologies and tools such...
# 324   - Diving deep into lower-level libraries like ...
# 1491  - Experience in an environment where cybersecu...
# 1815  - Docker\n  - AUTOSAR (AUTomotive Open System ...
# 2174  - Experience of Linux kernel and system progra...
#
#                                     Responsibilities_GT  \
# 1575  - Designing and implementing new screens in th...
# 324   (list out or say "Not mentioned")\n  - Your wo...
# 1491  - Primarily focus on backend development for t...
# 1815  - Work inside an intercultural team of many la...
# 2174                                      Not mentioned
#
#                                             Benefits_GT
# 1575  - Opportunity to participate in integration ev...
# 324                                       Not mentioned
# 1491  - 28 vacation days + the option to purchase 10...
# 1815                                      Not mentioned
# 2174  - An early finish on Fridays\n  - Bonus Privat...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Chat GPT's version

# %%
system_prompt = """
You are an AI assistant. Your role is to extract specific information from job descriptions and format them in a strict structure.
"""

user_prompt = """
I will provide a job description. Please extract and present the information in **this exact order**:

1. Platform: (Android/iOS/Cross-platform)
2. Salary: (If stated; otherwise "Not mentioned")
3. Requirements: (verbatim from the job description or "Not mentioned")
4. Nice to have: (verbatim or "Not mentioned")
5. Responsibilities: (verbatim or "Not mentioned")
6. Benefits: (verbatim or "Not mentioned")

**Guidelines**:
- **DO NOT reword, paraphrase, or summarize** any part of the job description. Copy the sentences exactly as they appear.
- Combine all mandatory or required skill sections (e.g., "Requirements," "Skills," "Key Technologies," "About You") under **Requirements**.
- If the job description specifically says something is "a plus," "beneficial," or otherwise indicates it’s optional, place it under "Nice to have" even if it appears under a "Requirements" heading in the job description.
- If there is an "About you" or "About Role" section (or similar) that describs duties or tasks, include those under "Responsibilities".
- If the information is not in the job description, write "Not mentioned" for that section.
- For multiple platforms (e.g., Android, iOS), list them all in **Platform** and use headings under Requirements (and other sections, if needed) like "General Requirements:", "For Android Developers:", "For iOS Developers:".
- Present your answer **only** in the format above.

---
Here is the job description:
"""

df_split = await chat_gpt.chatgpt_async(
    input_column_name="Job Description English", 
    output_column_name="Job Description Extracted",
    input_text_length=None,
    output_text_length=None,
    num_rows=None,  
    df=test.copy(), 
    system_prompt=system_prompt,
    user_prompt=user_prompt,
    gpt_model="gpt-4o-2024-11-20",
    client=client_async,
    batch_size=5,
    concurrency_limit=10,
    cache_file="../data/cache/job_description_extracted_cache_gpt-4o-2024-11-20.json"
)

df_split.head()
# Out:
# Processing Batches: 100%|██████████| 7/7 [00:14<00:00,  2.10s/it]
#             Location            Region  EU Member  Schengen Agreement  \
# 1575          Poland            Europe       True                True
# 324           Canada  Northern America      False               False
# 1491     Netherlands            Europe       True                True
# 1815         Romania            Europe       True                True
# 2174  United Kingdom            Europe      False               False
#
#      Google Domain Type Google Domain Used  \
# 1575            default         google.com
# 324             default         google.com
# 1491            default         google.com
# 1815            default         google.com
# 2174            default         google.com
#
#                                   Job Title Company Name  \
# 1575                      Android Developer   Connectis_
# 324                  iOS Developer (Remote)       McAfee
# 1491                          IOS developer    StarApple
# 1815         Android Developer / CTS Expert       Luxoft
# 2174  Embedded Software Developer (Android)    Integrity
#
#                     Job Location             Apply Options  ... Language  \
# 1575              Kórnik, Poland               HitPraca.pl  ...       pl
# 324         Waterloo, ON, Canada                     Blind  ...       en
# 1491      Eindhoven, Netherlands             Werkzoeken.nl  ...       nl
# 1815                     Romania  Indeed, Jooble, LinkedIn  ...       en
# 2174  Chesterton, United Kingdom                 SitePoint  ...       en
#
#                                 Job Description English  \
# 1575  **Android Developer**  \r\n**Location:** Pozna...
# 324   Role OverviewMcAfee is searching for an interm...
# 1491  **Organization & Department**\r\n\r\nAre you i...
# 1815  Remote Romania, Romania\r\n\r\nAndroid\r\n\r\n...
# 2174  If you have experience developing embedded rea...
#
#                                            Ground Truth Platform_GT  \
# 1575  1. Platform: Android\n2. Salary: Not mentioned...     Android
# 324   1. Platform: iOS\n2. Salary: Not mentioned\n3....         iOS
# 1491  1. Platform: iOS\n2. Salary: €3,200 to €5,000\...         iOS
# 1815  1. Platform: Android\n2. Salary: Not mentioned...     Android
# 2174  1. Platform: Android\n2. Salary: £40-50K plus ...     Android
#
#                   Salary_GT  \
# 1575          Not mentioned
# 324           Not mentioned
# 1491       €3,200 to €5,000
# 1815          Not mentioned
# 2174  £40-50K plus benefits
#
#                                         Requirements_GT  \
# 1575  - Minimum 3 years of commercial experience as ...
# 324   - You can develop iOS applications at an inter...
# 1491  - 3 years of work experience with Swift\n  - B...
# 1815  - Deep expertise in Google CTS tests\n  - Stro...
# 2174  - Degree in relevant subject\n  - Embedded rea...
#
#                                         Nice to have_GT  \
# 1575  - Familiarity with technologies and tools such...
# 324   - Diving deep into lower-level libraries like ...
# 1491  - Experience in an environment where cybersecu...
# 1815  - Docker\n  - AUTOSAR (AUTomotive Open System ...
# 2174  - Experience of Linux kernel and system progra...
#
#                                     Responsibilities_GT  \
# 1575  - Designing and implementing new screens in th...
# 324   (list out or say "Not mentioned")\n  - Your wo...
# 1491  - Primarily focus on backend development for t...
# 1815  - Work inside an intercultural team of many la...
# 2174                                      Not mentioned
#
#                                             Benefits_GT  \
# 1575  - Opportunity to participate in integration ev...
# 324                                       Not mentioned
# 1491  - 28 vacation days + the option to purchase 10...
# 1815                                      Not mentioned
# 2174  - An early finish on Fridays\n  - Bonus Privat...
#
#                               Job Description Extracted
# 1575  1. Platform: Android  \n2. Salary: Not mention...
# 324   1. Platform: iOS/macOS  \n2. Salary: Not menti...
# 1491  1. Platform: iOS  \n2. Salary: €3,200 to €5,00...
# 1815  1. Platform: Android  \n2. Salary: Not mention...
# 2174  1. Platform: Android  \n2. Salary: £40-50K plu...
#
# [5 rows x 28 columns]

# %%
tests_helpers.column_to_txt(column='Job Description Extracted', output="../data/ground_truth/job_descriptions_chatgpt.txt", df=df_split)

# %% [markdown]
# ### Split Chat GPT's version into sections

# %%
df_split["Platform_GPT"] = df_split["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"1\. Platform"))
df_split["Salary_GPT"] = df_split["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"2\. Salary"))
df_split["Requirements_GPT"] = df_split["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"3\. Requirements"))
df_split["Nice to have_GPT"] = df_split["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"4\. Nice to have"))
df_split["Responsibilities_GPT"] = df_split["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"5\. Responsibilities"))
df_split["Benefits_GPT"] = df_split["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"6\. Benefits"))

df_split.head()
# Out:
#             Location            Region  EU Member  Schengen Agreement  \
# 1575          Poland            Europe       True                True
# 324           Canada  Northern America      False               False
# 1491     Netherlands            Europe       True                True
# 1815         Romania            Europe       True                True
# 2174  United Kingdom            Europe      False               False
#
#      Google Domain Type Google Domain Used  \
# 1575            default         google.com
# 324             default         google.com
# 1491            default         google.com
# 1815            default         google.com
# 2174            default         google.com
#
#                                   Job Title Company Name  \
# 1575                      Android Developer   Connectis_
# 324                  iOS Developer (Remote)       McAfee
# 1491                          IOS developer    StarApple
# 1815         Android Developer / CTS Expert       Luxoft
# 2174  Embedded Software Developer (Android)    Integrity
#
#                     Job Location             Apply Options  ...  \
# 1575              Kórnik, Poland               HitPraca.pl  ...
# 324         Waterloo, ON, Canada                     Blind  ...
# 1491      Eindhoven, Netherlands             Werkzoeken.nl  ...
# 1815                     Romania  Indeed, Jooble, LinkedIn  ...
# 2174  Chesterton, United Kingdom                 SitePoint  ...
#
#                                         Nice to have_GT  \
# 1575  - Familiarity with technologies and tools such...
# 324   - Diving deep into lower-level libraries like ...
# 1491  - Experience in an environment where cybersecu...
# 1815  - Docker\n  - AUTOSAR (AUTomotive Open System ...
# 2174  - Experience of Linux kernel and system progra...
#
#                                     Responsibilities_GT  \
# 1575  - Designing and implementing new screens in th...
# 324   (list out or say "Not mentioned")\n  - Your wo...
# 1491  - Primarily focus on backend development for t...
# 1815  - Work inside an intercultural team of many la...
# 2174                                      Not mentioned
#
#                                             Benefits_GT  \
# 1575  - Opportunity to participate in integration ev...
# 324                                       Not mentioned
# 1491  - 28 vacation days + the option to purchase 10...
# 1815                                      Not mentioned
# 2174  - An early finish on Fridays\n  - Bonus Privat...
#
#                               Job Description Extracted Platform_GPT  \
# 1575  1. Platform: Android  \n2. Salary: Not mention...      Android
# 324   1. Platform: iOS/macOS  \n2. Salary: Not menti...    iOS/macOS
# 1491  1. Platform: iOS  \n2. Salary: €3,200 to €5,00...          iOS
# 1815  1. Platform: Android  \n2. Salary: Not mention...      Android
# 2174  1. Platform: Android  \n2. Salary: £40-50K plu...      Android
#
#                  Salary_GPT  \
# 1575          Not mentioned
# 324           Not mentioned
# 1491       €3,200 to €5,000
# 1815          Not mentioned
# 2174  £40-50K plus benefits
#
#                                        Requirements_GPT  \
# 1575  - Minimum 3 years of commercial experience as ...
# 324   - You can develop iOS applications at an inter...
# 1491  - 3 years of work experience with Swift  \n   ...
# 1815  - Deep expertise in Google CTS tests  \n   - S...
# 2174  - Degree in relevant subject  \n   - Embedded ...
#
#                                        Nice to have_GPT  \
# 1575  - Familiarity with technologies and tools such...
# 324   - Diving deep into lower-level libraries like ...
# 1491  - Experience in an environment where cybersecu...
# 1815  - Docker  \n   - AUTOSAR (AUTomotive Open Syst...
# 2174  - Experience of Linux kernel and system progra...
#
#                                    Responsibilities_GPT  \
# 1575  - Designing and implementing new screens in th...
# 324   - Dive deep into anti-censorship technologies ...
# 1491  - You’ll primarily focus on backend developmen...
# 1815  - Work inside an intercultural team of many la...
# 2174  - Develop and support the software running on ...
#
#                                            Benefits_GPT
# 1575  - Opportunity to participate in integration ev...
# 324                                       Not mentioned
# 1491  - 28 vacation days + the option to purchase 10...
# 1815                                      Not mentioned
# 2174  - An early finish on Fridays  \n   - Bonus  \n...
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Calculate fuzzy scores
#
# 1. Token Sort Ratio (Handling Word Order Differences)<br>
# If two sentences contain the same words but in different order, Levenshtein distance alone might give a low similarity score. Instead, we:
# - Split both sentences into words.
# - Sort them alphabetically.
# - Recalculate Levenshtein Distance.
#
# 2. Token Set Ratio (Handling Partial Overlaps)<br>
# If one string is a subset of another, Token Set Ratio helps:
# - Convert both sentences into sets of unique words.
# - Compare only the common words.

# %%
tests_helpers.compare_fuzzy_sections(df_split)
# Out:
# Average Token Set Ratio per section:
# Platform: 98.33
# Salary: 99.98
# Requirements: 98.61
# Nice to have: 93.38
# Responsibilities: 91.42
# Benefits: 91.85
#
# Overall Average Token Set Ratio: 95.60

# %% [markdown]
# ## Extract technologies and tools

# %%
df_filtered = pd.read_csv('../data/csv/df_filtered.csv').copy()
df_filtered.head()
# Out:
#   Location  Region  EU Member  Schengen Agreement Google Domain Type  \
# 0  Austria  Europe       True                True            default
# 1  Austria  Europe       True                True            default
# 2  Austria  Europe       True                True            default
# 3  Austria  Europe       True                True            default
# 4  Austria  Europe       True                True            default
#
#   Google Domain Used                                          Job Title  \
# 0         google.com  Android Developer – Kotlin (Austria based, Hyb...
# 1         google.com                       ios entwickler 80–100% w/m/d
# 2         google.com                               Middle iOS developer
# 3         google.com                                      iOS Developer
# 4         google.com                              iOS Software Engineer
#
#              Company Name       Job Location  \
# 0    Bitcoin Devs Company    Vienna, Austria
# 1  CHANCENLAND VORARLBERG  Dornbirn, Austria
# 2              Processica    Vienna, Austria
# 3       Raiffeisen Gruppe      Linz, Austria
# 4               Cybermoth    Vienna, Austria
#
#                                    Apply Options  ...       Search Query  \
# 0                                          Jobs3  ...  Android developer
# 1          IT-Career.at, STEMJOBS.AT, IT-JOBS.AT  ...      iOS developer
# 2                                         JOBITT  ...      iOS developer
# 3  Jooble, Trabajo.org - Stellenangebote, Arbeit  ...      iOS developer
# 4                          Expertini, Talent.com  ...      iOS developer
#
#   Language                            Job Description English  \
# 0       en  Overview:\r\nThe Android Developer – Kotlin po...
# 1       de  **iOS Developer 80–100% w/m/d**\r\n\r\n**Job D...
# 2       en  Looking for a iOS Developer. Playing well in a...
# 3       de  **Your Role in the Team**  \r\n- You contribut...
# 4       en  We are searching for iOS Software Engineers wi...
#
#                            Job Description Extracted Platform  \
# 0  1. Platform: Android  \r\n2. Salary: Not menti...  Android
# 1  1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
# 2  1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
# 3  1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
# 4  1. Platform: iOS  \r\n2. Salary: Depending on ...      iOS
#
#                                             Salary_E  \
# 0                                      Not mentioned
# 1                                      Not mentioned
# 2                                      Not mentioned
# 3                                      Not mentioned
# 4  Depending on qualifications and professional e...
#
#                                         Requirements   Nice to have  \
# 0  • Passionate about mobile platforms and transl...  Not mentioned
# 1  - **Motivation over experience:** Curiosity, i...  Not mentioned
# 2  Playing well in a team and has strong analytic...  Not mentioned
# 3  - You are familiar with Continuous Integration...  Not mentioned
# 4  • Worked on at least one native Swift applicat...  Not mentioned
#
#                                     Responsibilities  \
# 0  • Ensure that the app meets our quality standa...
# 1  - You will work with us on exciting projects f...
# 2                                      Not mentioned
# 3  - You contribute to the further development of...
# 4  • In this position you will be part of one or ...
#
#                                             Benefits
# 0                                      Not mentioned
# 1  - A compact, battle-tested team and flat hiera...
# 2                                      Not mentioned
# 3  - Home Office  \r\n   - Flexible working hours...
# 4  • You will be part of a company with an inspir...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Merge 3 columns into 1

# %%
df_sample = df_filtered.sample(n=40, random_state=42)

df_sample["Full Requirements"] = (
    "3. Requirements:\n" + df_sample["Requirements"].astype(str) + "\n\n" +
    "4. Nice to have:\n" + df_sample["Nice to have"].astype(str) + "\n\n" +
    "5. Responsibilities:\n" + df_sample["Responsibilities"].astype(str)
)
df_sample.head()
# Out:
#       Location            Region  EU Member  Schengen Agreement  \
# 282     Canada  Northern America      False               False
# 479     France            Europe       True                True
# 1307   Romania            Europe       True                True
# 1254  Portugal            Europe       True                True
# 507    Germany            Europe       True                True
#
#      Google Domain Type Google Domain Used  \
# 282             default         google.com
# 479             default         google.com
# 1307              local          google.ro
# 1254            default         google.com
# 507             default         google.com
#
#                                               Job Title     Company Name  \
# 282        Développeur iOS senior -Senior iOS Developer          OneSpan
# 479   Senior Android Developer - Video Expert (All G...      Dailymotion
# 1307                                      iOS Developer  ASSIST SOFTWARE
# 1254                    Principal iOS Software Engineer              Sky
# 507       iOS Developer - Health Care App (m/w/d) Trier        HIBA GmbH
#
#                   Job Location  \
# 282   Montreal, Quebec, Canada
# 479              Paris, France
# 1307          Suceava, Romania
# 1254          Aveiro, Portugal
# 507             Trier, Germany
#
#                                           Apply Options  ... Language  \
# 282   Greenhouse, Indeed, Kovasys IT Recruitment Age...  ...       fr
# 479                                            Ivy Exec  ...       en
# 1307                                           IOS Jobs  ...       en
# 1254                               Empregos Trabajo.org  ...       en
# 507                                                XING  ...       de
#
#                                 Job Description English  \
# 282   The English translation for the job descriptio...
# 479   Company Description\r\n\r\nDailymotion is the ...
# 1307  Are you an iOS mobile innovator? We need you! ...
# 1254  Role Overview\r\n\r\nSky Portugal is a leading...
# 507   **iOS Developer - Health Care App (m/f/d) Trie...
#
#                               Job Description Extracted Platform  \
# 282   1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
# 479   1. Platform: Android  \r\n2. Salary: Not menti...  Android
# 1307  1. Platform: iOS  \r\n2. Salary: Competitive s...      iOS
# 1254  1. Platform: iOS  \r\n2. Salary: $120,000 - $1...      iOS
# 507   1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
#
#                            Salary_E  \
# 282                   Not mentioned
# 479                   Not mentioned
# 1307             Competitive salary
# 1254  $120,000 - $180,000 per annum
# 507                   Not mentioned
#
#                                            Requirements  \
# 282                                       Not mentioned
# 479   • Excellent knowledge of Android SDK  \r\n   •...
# 1307  • Ability to design and implement iOS applicat...
# 1254  • 5+ years of experience in native iOS develop...
# 507   - Completed degree in computer science or a co...
#
#                                            Nice to have  \
# 282                                       Not mentioned
# 479   • Proven experience in developing video-based ...
# 1307  • Experience with Phonegap, HTML5  \r\n   • Ad...
# 1254                                      Not mentioned
# 507                                       Not mentioned
#
#                                        Responsibilities  \
# 282                                       Not mentioned
# 479   • Design and build advanced applications for t...
# 1307                                      Not mentioned
# 1254  • Design, develop, and deliver high-quality so...
# 507   - Development and maintenance of iOS applicati...
#
#                                                Benefits  \
# 282                                       Not mentioned
# 479                                       Not mentioned
# 1307  Relocation package for 2 months  \r\n   Employ...
# 1254  • Above market salary  \r\n   • Yearly bonus  ...
# 507   - Continuous training opportunities to ensure ...
#
#                                       Full Requirements
# 282   3. Requirements:\nNot mentioned\n\n4. Nice to ...
# 479   3. Requirements:\n• Excellent knowledge of And...
# 1307  3. Requirements:\n• Ability to design and impl...
# 1254  3. Requirements:\n• 5+ years of experience in ...
# 507   3. Requirements:\n- Completed degree in comput...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Columns into text

# %%
tests_helpers.column_to_txt(column='Full Requirements', output="../data/ground_truth/Full_requirements_sample.txt", df=df_sample)

# %% [markdown]
# ###  Load ground truth into a DataFrame

# %%
df_sample = tests_helpers.txt_to_column(txt_path="../data/ground_truth/Full_requirements_ground_truth.txt", df=df_sample)
df_sample.head()
# Out:
#       Location            Region  EU Member  Schengen Agreement  \
# 282     Canada  Northern America      False               False
# 479     France            Europe       True                True
# 1307   Romania            Europe       True                True
# 1254  Portugal            Europe       True                True
# 507    Germany            Europe       True                True
#
#      Google Domain Type Google Domain Used  \
# 282             default         google.com
# 479             default         google.com
# 1307              local          google.ro
# 1254            default         google.com
# 507             default         google.com
#
#                                               Job Title     Company Name  \
# 282        Développeur iOS senior -Senior iOS Developer          OneSpan
# 479   Senior Android Developer - Video Expert (All G...      Dailymotion
# 1307                                      iOS Developer  ASSIST SOFTWARE
# 1254                    Principal iOS Software Engineer              Sky
# 507       iOS Developer - Health Care App (m/w/d) Trier        HIBA GmbH
#
#                   Job Location  \
# 282   Montreal, Quebec, Canada
# 479              Paris, France
# 1307          Suceava, Romania
# 1254          Aveiro, Portugal
# 507             Trier, Germany
#
#                                           Apply Options  ...  \
# 282   Greenhouse, Indeed, Kovasys IT Recruitment Age...  ...
# 479                                            Ivy Exec  ...
# 1307                                           IOS Jobs  ...
# 1254                               Empregos Trabajo.org  ...
# 507                                                XING  ...
#
#                                 Job Description English  \
# 282   The English translation for the job descriptio...
# 479   Company Description\r\n\r\nDailymotion is the ...
# 1307  Are you an iOS mobile innovator? We need you! ...
# 1254  Role Overview\r\n\r\nSky Portugal is a leading...
# 507   **iOS Developer - Health Care App (m/f/d) Trie...
#
#                               Job Description Extracted Platform  \
# 282   1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
# 479   1. Platform: Android  \r\n2. Salary: Not menti...  Android
# 1307  1. Platform: iOS  \r\n2. Salary: Competitive s...      iOS
# 1254  1. Platform: iOS  \r\n2. Salary: $120,000 - $1...      iOS
# 507   1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
#
#                            Salary_E  \
# 282                   Not mentioned
# 479                   Not mentioned
# 1307             Competitive salary
# 1254  $120,000 - $180,000 per annum
# 507                   Not mentioned
#
#                                            Requirements  \
# 282                                       Not mentioned
# 479   • Excellent knowledge of Android SDK  \r\n   •...
# 1307  • Ability to design and implement iOS applicat...
# 1254  • 5+ years of experience in native iOS develop...
# 507   - Completed degree in computer science or a co...
#
#                                            Nice to have  \
# 282                                       Not mentioned
# 479   • Proven experience in developing video-based ...
# 1307  • Experience with Phonegap, HTML5  \r\n   • Ad...
# 1254                                      Not mentioned
# 507                                       Not mentioned
#
#                                        Responsibilities  \
# 282                                       Not mentioned
# 479   • Design and build advanced applications for t...
# 1307                                      Not mentioned
# 1254  • Design, develop, and deliver high-quality so...
# 507   - Development and maintenance of iOS applicati...
#
#                                                Benefits  \
# 282                                       Not mentioned
# 479                                       Not mentioned
# 1307  Relocation package for 2 months  \r\n   Employ...
# 1254  • Above market salary  \r\n   • Yearly bonus  ...
# 507   - Continuous training opportunities to ensure ...
#
#                                       Full Requirements  \
# 282   3. Requirements:\nNot mentioned\n\n4. Nice to ...
# 479   3. Requirements:\n• Excellent knowledge of And...
# 1307  3. Requirements:\n• Ability to design and impl...
# 1254  3. Requirements:\n• 5+ years of experience in ...
# 507   3. Requirements:\n- Completed degree in comput...
#
#                                            Ground Truth
# 282                                                  {}
# 479   {\n   "languages_and_runtimes": ["Kotlin", "co...
# 1307  {\n   "languages_and_runtimes": ["Objective-C"...
# 1254  {\n   "languages_and_runtimes":["Swift"],\n   ...
# 507   {\n   "languages_and_runtimes": ["Objective-C"...
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Chat GPT's version

# %%
system_prompt_1 = """
You are a senior extraction assistant.

GOAL
Given a natural-language job-vacancy text, return one and only one
valid, minified JSON object that maps every technology term found in
the input to exactly ONE key from ALLOWED_KEYS.

STRICT RULES
1. Output = raw JSON only (no Markdown, no comments, no extra text).
2. Use keys from ALLOWED_KEYS exactly as written. Omit any key whose array would be empty.
3. Each value is an **array of unique strings**, sorted alphabetically and preserving the term’s original spelling/case from the input.
4. Ignore soft skills and vague nouns (e.g. communication, documentation, performance, detail, English, collaboration, problem-solving, university).
5. **IGNORE** overly generic technology words/phrases (e.g. "design patterns", "android ui", "json", "xml", "clean code", "API integration", "unit testing", "Continuous integration", "CI", "CD", "CI/CD", "cryptography", "application testing" ect.).
6. DO NOT hallucinate. Include a term **only** if it appears verbatim in the input text.
7. If a technology term matches **exactly** (case-insensitive) one of the values in ALLOWED_KEYS, then it MUST be assigned to that exact key — even if the name could hypothetically fit other categories.
8. The order of keys in the output JSON MUST strictly follow the order of keys as they appear in the ALLOWED_KEYS section below. Only include keys that have at least one matched term. If a key has no matched terms, it MUST be completely omitted from the output, even if this breaks the visual continuity of the ALLOWED_KEYS order.


ALLOWED_KEYS (with examples)
{
    "languages_and_runtimes": ["Swift", "Kotlin", "Java", "Dart", "Objective-C", "Coroutines", "RxSwift", "Combine", "GCD", "RxJava", "Flows", "JavaScript", "TypeScript", "C", "C++", "Python", "Golang", "PHP"],
    "ui_and_cross_platform_frameworks": ["SwiftUI", "UIKit", "Jetpack Compose", "Flutter", "React Native", "Xamarin", "Ionic", "WatchKit", "Cocoa Touch", "PhoneGap", "Cordova", "Kotlin Multiplatform"],
    "architectural_patterns": ["MVVM", "VIPER", "Clean Architecture", "MVI", "MVC", "MVP", "Redux"],
    "dependency_injection_frameworks": ["Dagger", "Hilt", "Koin", "Swinject"],
    "build_and_dependency_management": ["Gradle", "CocoaPods", "SPM", "Bazel", "Buck", "Xcode", "Android Studio", "CircleCI", "Bamboo", "CocoaPods"],
    "data_and_caching": ["Core Data", "Room", "Realm", "SQLite", "Firestore", "MongoDB", "SAP UltraLite", "MySQL", "NoSQL"],
    "networking_and_api": ["Retrofit", "OkHttp", "URLSession", "Alamofire", "GraphQL", "REST API", "WebSockets", "gRPC", "Protocol Buffers"],
    "backend_or_baas_integration": ["Firebase", "AWS Amplify", "Azure Mobile", "Parse", "AWS Mobile Hub", "AWS Cognito", "AWS S3"],
    "device_and_platform_services_and_third_party_sdks": ["ARKit", "HealthKit", "CoreML", "Core Animation", "Android SDK", "Android NDK", "Push Notifications", "BLE", "NFC", "Camera", "Location", "Sensors", "Stripe SDK", "Facebook SDK", "AdMob", "Google Maps", "ExoPlayer", "Glide", "Stripe", "PayPal SDK", "Binder", "AIDL", "JNI", "CTS", "HAL", "LoRa", "CarPlay", "Android Auto", "CydiaSubstrate", "Frida", "WebViews"],
    "security_and_cryptography": ["Keychain", "TLS pinning", "OAuth2", "Veracode", "Checkmarx", "OWASP"],
    "testing_frameworks": ["XCTest", "JUnit", "Espresso", "Mockito", "Robolectric"],
    "debugging_or_profiling": ["Instruments", "Android Profiler"],
    "version_control": ["Git", "GIT", "git", "SVN", "Mercurial", "Gerrit", "GitFlow", "SourceTree", "Fork", "Bitbucket"],
    "ci_cd_and_release_automation": ["GitHub Actions", "Jenkins", "Bitrise", "fastlane", "CircleCI", "Bamboo", "GitLab CI", "Docker"],
    "monitoring_analytics_and_crash_reporting": ["Crashlytics", "Sentry", "Datadog", "Firebase Analytics", "App Center"],
    "development_methodologies": ["Scrum", "Kanban", "Agile", "SAFe", "TDD", "BDD", "DevOps"],
    "testing_process_and_qa": ["test coverage", "regression testing"],
    "code_quality_and_static_analysis": ["SonarQube", "SwiftLint", "Veracode", "Checkmarx"],
    "documentation_and_knowledge_sharing": ["Swagger", "OpenAPI", "Javadoc", "Confluence", "HIG"],
    "collaboration_pm_and_design_handoff": ["Jira", "Trello", "Figma", "Zeplin", "Rally/AgileCentral"],
    "distribution_and_store_operations": ["TestFlight", "App Store Connect", "Google Play Console"],
    "compliance_and_certifications": ["SOC 2", "GDPR"]
}

EXAMPLE RESPONSE
{
    "languages_and_runtimes":["Swift","Java"],
    "version_control":["Git"]
}
"""


user_prompt_1 = """
Extract every technology, tool, framework, library, service or formal
methodology mentioned in the text below and output the JSON exactly as
specified in the system prompt.

---
INPUT TEXT:
"""


df_extracted_1 = await chat_gpt.chatgpt_async(
    input_column_name="Full Requirements", 
    output_column_name="Extracted Technologies GPT",
    input_text_length=None,
    output_text_length=None,
    num_rows=None,  
    df=df_sample.copy(), 
    system_prompt=system_prompt_1,
    user_prompt=user_prompt_1,
    gpt_model="gpt-4o-2024-11-20",
    client=client_async,
    batch_size=40,
    concurrency_limit=40,
    cache_file= "../data/cache/Full_requirements_cache.json"
)
df_extracted_1.head()
# Out:
# Processing Batches: 100%|██████████| 1/1 [00:00<00:00, 25.07it/s]
#       Location            Region  EU Member  Schengen Agreement  \
# 282     Canada  Northern America      False               False
# 479     France            Europe       True                True
# 1307   Romania            Europe       True                True
# 1254  Portugal            Europe       True                True
# 507    Germany            Europe       True                True
#
#      Google Domain Type Google Domain Used  \
# 282             default         google.com
# 479             default         google.com
# 1307              local          google.ro
# 1254            default         google.com
# 507             default         google.com
#
#                                               Job Title     Company Name  \
# 282        Développeur iOS senior -Senior iOS Developer          OneSpan
# 479   Senior Android Developer - Video Expert (All G...      Dailymotion
# 1307                                      iOS Developer  ASSIST SOFTWARE
# 1254                    Principal iOS Software Engineer              Sky
# 507       iOS Developer - Health Care App (m/w/d) Trier        HIBA GmbH
#
#                   Job Location  \
# 282   Montreal, Quebec, Canada
# 479              Paris, France
# 1307          Suceava, Romania
# 1254          Aveiro, Portugal
# 507             Trier, Germany
#
#                                           Apply Options  ...  \
# 282   Greenhouse, Indeed, Kovasys IT Recruitment Age...  ...
# 479                                            Ivy Exec  ...
# 1307                                           IOS Jobs  ...
# 1254                               Empregos Trabajo.org  ...
# 507                                                XING  ...
#
#                               Job Description Extracted Platform  \
# 282   1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
# 479   1. Platform: Android  \r\n2. Salary: Not menti...  Android
# 1307  1. Platform: iOS  \r\n2. Salary: Competitive s...      iOS
# 1254  1. Platform: iOS  \r\n2. Salary: $120,000 - $1...      iOS
# 507   1. Platform: iOS  \r\n2. Salary: Not mentioned...      iOS
#
#                            Salary_E  \
# 282                   Not mentioned
# 479                   Not mentioned
# 1307             Competitive salary
# 1254  $120,000 - $180,000 per annum
# 507                   Not mentioned
#
#                                            Requirements  \
# 282                                       Not mentioned
# 479   • Excellent knowledge of Android SDK  \r\n   •...
# 1307  • Ability to design and implement iOS applicat...
# 1254  • 5+ years of experience in native iOS develop...
# 507   - Completed degree in computer science or a co...
#
#                                            Nice to have  \
# 282                                       Not mentioned
# 479   • Proven experience in developing video-based ...
# 1307  • Experience with Phonegap, HTML5  \r\n   • Ad...
# 1254                                      Not mentioned
# 507                                       Not mentioned
#
#                                        Responsibilities  \
# 282                                       Not mentioned
# 479   • Design and build advanced applications for t...
# 1307                                      Not mentioned
# 1254  • Design, develop, and deliver high-quality so...
# 507   - Development and maintenance of iOS applicati...
#
#                                                Benefits  \
# 282                                       Not mentioned
# 479                                       Not mentioned
# 1307  Relocation package for 2 months  \r\n   Employ...
# 1254  • Above market salary  \r\n   • Yearly bonus  ...
# 507   - Continuous training opportunities to ensure ...
#
#                                       Full Requirements  \
# 282   3. Requirements:\nNot mentioned\n\n4. Nice to ...
# 479   3. Requirements:\n• Excellent knowledge of And...
# 1307  3. Requirements:\n• Ability to design and impl...
# 1254  3. Requirements:\n• 5+ years of experience in ...
# 507   3. Requirements:\n- Completed degree in comput...
#
#                                            Ground Truth  \
# 282                                                  {}
# 479   {\n   "languages_and_runtimes": ["Kotlin", "co...
# 1307  {\n   "languages_and_runtimes": ["Objective-C"...
# 1254  {\n   "languages_and_runtimes":["Swift"],\n   ...
# 507   {\n   "languages_and_runtimes": ["Objective-C"...
#
#                              Extracted Technologies GPT
# 282                                                  {}
# 479   {\n    "languages_and_runtimes":["Kotlin","Cor...
# 1307  {\n    "languages_and_runtimes":["Objective-C"...
# 1254  {\n    "languages_and_runtimes":["Swift"],\n  ...
# 507   {\n    "languages_and_runtimes":["Objective-C"...
#
# [5 rows x 30 columns]

# %%
tests_helpers.column_to_txt(column='Extracted Technologies GPT', output="../data/ground_truth/Full_requirements_ground_chatgpt.txt", df=df_extracted_1)

# %% [markdown]
# ### Calculate fuzzy scores

# %%
df_extracted_1["Token Set Ratio"] = (df_extracted_1.apply(lambda row: tests_helpers.technologies_token_set_ratio(row["Ground Truth"], row["Extracted Technologies GPT"]),axis=1,).round(2))
print("Average Token Set Ratio :", df_extracted_1["Token Set Ratio"].mean().round(2))
# Out:
# Average Token Set Ratio : 98.71
