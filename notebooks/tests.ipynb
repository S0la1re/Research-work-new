# %% [markdown]
# # Tests
# ## Split job descriptions into structured sections

# %%
import os
import sys
import openai
import pandas as pd
from dotenv import load_dotenv


src_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'src'))
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# %load_ext autoreload
# %autoreload 2

from jobs_tools import tests_helpers, chat_gpt


load_dotenv()
client_async = openai.AsyncOpenAI()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv("../data/csv/df_translated.csv")

df.head()
# Out:
#   Location  Region  EU Member  Schengen Agreement Google Domain Type  \
# 0  Austria  Europe       True                True              local
# 1  Austria  Europe       True                True            default
# 2  Austria  Europe       True                True            default
# 3  Austria  Europe       True                True            default
# 4  Austria  Europe       True                True            default
#
#   Google Domain Used                                          Job Title  \
# 0          google.at  Sandbox Innovation Sdn. Bhd. | Senior Mobile A...
# 1         google.com                               Senior Ios Developer
# 2         google.com                   iOS Developer - Permanent remote
# 3         google.com                                  Sr. Ios Developer
# 4         google.com                             Software Engineer/ iOS
#
#                       Company Name Job Location  \
# 0                  Tideri Jobbörse      Austria
# 1      Pyramid Global Technologies      Austria
# 2  Bluestorm Recruitment by Dazzle      Austria
# 3                            Bykon      Austria
# 4                         Bitpanda     Anywhere
#
#                                        Apply Options  ... Work from home  \
# 0              Trabajo.org - Stellenangebote, Arbeit  ...            NaN
# 1  Trabajo.org - Stellenangebote, Arbeit, StudySm...  ...            NaN
# 2                                             Jooble  ...            NaN
# 3              Trabajo.org - Stellenangebote, Arbeit  ...            NaN
# 4                                           GrabJobs  ...           True
#
#   Salary Schedule type       Qualifications  \
# 0    NaN     Full-time                  NaN
# 1    NaN     Full-time  No degree mentioned
# 2    NaN     Full-time  No degree mentioned
# 3    NaN     Full-time                  NaN
# 4    NaN     Full-time  No degree mentioned
#
#                                               Job ID              Search Date  \
# 0  eyJqb2JfdGl0bGUiOiJTYW5kYm94IElubm92YXRpb24gU2...  2025-01-13 12:33:21 UTC
# 1  eyJqb2JfdGl0bGUiOiJTZW5pb3IgSW9zIERldmVsb3Blci...  2025-01-13 12:20:43 UTC
# 2  eyJqb2JfdGl0bGUiOiJpT1MgRGV2ZWxvcGVyIC0gUGVybW...  2025-01-13 12:20:43 UTC
# 3  eyJqb2JfdGl0bGUiOiJTci4gSW9zIERldmVsb3BlciIsIm...  2025-01-13 12:20:43 UTC
# 4  eyJqb2JfdGl0bGUiOiJTb2Z0d2FyZSBFbmdpbmVlci8gaU...  2025-01-13 12:20:43 UTC
#
#     Search Query Language Confidence  \
# 0  iOS developer       en   0.999997
# 1  iOS developer       en   0.999996
# 2  iOS developer       en   0.999994
# 3  iOS developer       en   0.999997
# 4  iOS developer       en   0.999996
#
#                              Job Description English
# 0  We are a dynamic FinTech company headquartered...
# 1  A minimum of 6+ years of concurrent commercial...
# 2  iOS Developer\r\n\r\nOur client is a leading m...
# 3  In ByKon we're looking for an exceptional Sr.\...
# 4  Who we are\r\n\r\nWe simplify wealth creation....
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Columns into text

# %%
sample = df.sample(n=30, random_state=42)

#tests_helpers.column_to_txt(column='Job Description English', output="../data/ground truth/job_descriptions_sample.txt", df=sample)

# %% [markdown]
# ### Load ground truth into DataFrame

# %%
test = tests_helpers.txt_to_column(txt_path="../data/ground truth/job_descriptions_ground_truth.txt", df=sample)
test.head()
# Out:
#            Location            Region  EU Member  Schengen Agreement  \
# 2089    Switzerland            Europe      False                True
# 2806  United States  Northern America      False               False
# 1146          Italy            Europe       True                True
# 1110          Italy            Europe       True                True
# 196          Canada  Northern America      False               False
#
#      Google Domain Type Google Domain Used  \
# 2089            default         google.com
# 2806            default         google.com
# 1146            default         google.com
# 1110            default         google.com
# 196             default         google.com
#
#                                               Job Title  \
# 2089                            Senior Mobile Developer
# 2806             Android Developer (Must speak Spanish)
# 1146  CyberConsulthink | Opportunità Mobile Develope...
# 1110  iOS Mobile Application Developer - Design and ...
# 196                                Senior iOS Developer
#
#                 Company Name                                     Job Location  \
# 2089  Nembrini Consulting SA                                              NaN
# 2806             Hire Orbitt                                         Anywhere
# 1146        CyberConsulthink  Ascoli Piceno, Province of Ascoli Piceno, Italy
# 1110             Eidos D.O.O                                            Italy
# 196             Konrad Group                                         Anywhere
#
#                                           Apply Options  ...  \
# 2089                                         Learn4Good  ...
# 2806                                          Glassdoor  ...
# 1146     CyberConsulthink | Azienda Informatica Hi-Tech  ...
# 1110                                              BeBee  ...
# 196   Jobgether, Glassdoor, Recruiter Jobs, Trabajo....  ...
#
#                        Salary             Schedule type       Qualifications  \
# 2089  CHF 80K–CHF 100K a year                 Full-time                  NaN
# 2806            60–70 an hour                 Full-time                  NaN
# 1146                      NaN  Full-time and Contractor  No degree mentioned
# 1110                      NaN                 Full-time  No degree mentioned
# 196                       NaN                 Full-time  No degree mentioned
#
#                                                  Job ID  \
# 2089  eyJqb2JfdGl0bGUiOiJTZW5pb3IgTW9iaWxlIERldmVsb3...
# 2806  eyJqb2JfdGl0bGUiOiJBbmRyb2lkIERldmVsb3BlciAoTX...
# 1146  eyJqb2JfdGl0bGUiOiJDeWJlckNvbnN1bHRoaW5rIHwgT3...
# 1110  eyJqb2JfdGl0bGUiOiJpT1MgTW9iaWxlIEFwcGxpY2F0aW...
# 196   eyJqb2JfdGl0bGUiOiJTZW5pb3IgaU9TIERldmVsb3Blci...
#
#                   Search Date       Search Query Language Confidence  \
# 2089  2025-01-13 12:24:05 UTC      iOS developer       en   0.999996
# 2806  2025-01-13 12:12:29 UTC  Android developer       en   0.999997
# 1146  2025-01-13 12:22:26 UTC      iOS developer       it   0.999996
# 1110  2025-01-13 12:22:27 UTC      iOS developer       en   0.999997
# 196   2025-01-13 12:21:05 UTC      iOS developer       en   0.999996
#
#                                 Job Description English  \
# 2089  Location: Sandhubel\r\nOn behalf of a major cl...
# 2806  Job Title: Android Developer (Must speak Spani...
# 1146  Join the CyberConsulthink team. We are looking...
# 1110  Are you a skilled iOS developer looking for a ...
# 196   This a Full Remote job, the offer is available...
#
#                                            Ground Truth
# 2089  1. Platform: Android\n2. Salary: Not mentioned...
# 2806  1. Platform: iOS\n2. Salary: Not mentioned\n3....
# 1146  1. Platform: iOS\n2. Salary: €3,200 to €5,000\...
# 1110  1. Platform: Android\n2. Salary: Not mentioned...
# 196   1. Platform: Android\n2. Salary: £40-50K plus ...
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Split ground truth into sections

# %%
test["Platform_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"1\. Platform"))
test["Salary_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"2\. Salary"))
test["Requirements_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"3\. Requirements"))
test["Nice to have_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"4\. Nice to have"))
test["Responsibilities_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"5\. Responsibilities"))
test["Benefits_GT"] = test["Ground Truth"].apply(lambda x: tests_helpers.extract_section(x, r"6\. Benefits"))

test.head()
# Out:
#            Location            Region  EU Member  Schengen Agreement  \
# 2089    Switzerland            Europe      False                True
# 2806  United States  Northern America      False               False
# 1146          Italy            Europe       True                True
# 1110          Italy            Europe       True                True
# 196          Canada  Northern America      False               False
#
#      Google Domain Type Google Domain Used  \
# 2089            default         google.com
# 2806            default         google.com
# 1146            default         google.com
# 1110            default         google.com
# 196             default         google.com
#
#                                               Job Title  \
# 2089                            Senior Mobile Developer
# 2806             Android Developer (Must speak Spanish)
# 1146  CyberConsulthink | Opportunità Mobile Develope...
# 1110  iOS Mobile Application Developer - Design and ...
# 196                                Senior iOS Developer
#
#                 Company Name                                     Job Location  \
# 2089  Nembrini Consulting SA                                              NaN
# 2806             Hire Orbitt                                         Anywhere
# 1146        CyberConsulthink  Ascoli Piceno, Province of Ascoli Piceno, Italy
# 1110             Eidos D.O.O                                            Italy
# 196             Konrad Group                                         Anywhere
#
#                                           Apply Options  ... Language  \
# 2089                                         Learn4Good  ...       en
# 2806                                          Glassdoor  ...       en
# 1146     CyberConsulthink | Azienda Informatica Hi-Tech  ...       it
# 1110                                              BeBee  ...       en
# 196   Jobgether, Glassdoor, Recruiter Jobs, Trabajo....  ...       en
#
#      Confidence                            Job Description English  \
# 2089   0.999996  Location: Sandhubel\r\nOn behalf of a major cl...
# 2806   0.999997  Job Title: Android Developer (Must speak Spani...
# 1146   0.999996  Join the CyberConsulthink team. We are looking...
# 1110   0.999997  Are you a skilled iOS developer looking for a ...
# 196    0.999996  This a Full Remote job, the offer is available...
#
#                                            Ground Truth Platform_GT  \
# 2089  1. Platform: Android\n2. Salary: Not mentioned...     Android
# 2806  1. Platform: iOS\n2. Salary: Not mentioned\n3....         iOS
# 1146  1. Platform: iOS\n2. Salary: €3,200 to €5,000\...         iOS
# 1110  1. Platform: Android\n2. Salary: Not mentioned...     Android
# 196   1. Platform: Android\n2. Salary: £40-50K plus ...     Android
#
#                   Salary_GT  \
# 2089          Not mentioned
# 2806          Not mentioned
# 1146       €3,200 to €5,000
# 1110          Not mentioned
# 196   £40-50K plus benefits
#
#                                         Requirements_GT  \
# 2089  - Minimum 3 years of commercial experience as ...
# 2806  - You can develop iOS applications at an inter...
# 1146  - 3 years of work experience with Swift\n  - B...
# 1110  - Deep expertise in Google CTS tests\n  - Stro...
# 196   - Degree in relevant subject\n  - Embedded rea...
#
#                                         Nice to have_GT  \
# 2089  - Familiarity with technologies and tools such...
# 2806  - Diving deep into lower-level libraries like ...
# 1146  - Experience in an environment where cybersecu...
# 1110  - Docker\n  - AUTOSAR (AUTomotive Open System ...
# 196   - Experience of Linux kernel and system progra...
#
#                                     Responsibilities_GT  \
# 2089  - Designing and implementing new screens in th...
# 2806  (list out or say "Not mentioned")\n  - Your wo...
# 1146  - Primarily focus on backend development for t...
# 1110  - Work inside an intercultural team of many la...
# 196                                       Not mentioned
#
#                                             Benefits_GT
# 2089  - Opportunity to participate in integration ev...
# 2806                                      Not mentioned
# 1146  - 28 vacation days + the option to purchase 10...
# 1110                                      Not mentioned
# 196   - An early finish on Fridays\n  - Bonus Privat...
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Chat GPT's version

# %%
system_prompt = """
You are an AI assistant. Your role is to extract specific information from job descriptions and format them in a strict structure.
"""

user_prompt = """
I will provide a job description. Please extract and present the information in **this exact order**:

1. Platform: (Android/iOS/Cross-platform)
2. Salary: (If stated; otherwise "Not mentioned")
3. Requirements: (verbatim from the job description or "Not mentioned")
4. Nice to have: (verbatim or "Not mentioned")
5. Responsibilities: (verbatim or "Not mentioned")
6. Benefits: (verbatim or "Not mentioned")

**Guidelines**:
- **DO NOT reword, paraphrase, or summarize** any part of the job description. Copy the sentences exactly as they appear.
- Combine all mandatory or required skill sections (e.g., "Requirements," "Skills," "Key Technologies," "About You") under **Requirements**.
- If the job description specifically says something is "a plus," "beneficial," or otherwise indicates it’s optional, place it under "Nice to have" even if it appears under a "Requirements" heading in the job description.
- If there is an "About you" or "About Role" section (or similar) that describs duties or tasks, include those under "Responsibilities".
- If the information is not in the job description, write "Not mentioned" for that section.
- For multiple platforms (e.g., Android, iOS), list them all in **Platform** and use headings under Requirements (and other sections, if needed) like "General Requirements:", "For Android Developers:", "For iOS Developers:".
- Present your answer **only** in the format above.

---
Here is the job description:
"""

df_extracted_test = await chat_gpt.chatgpt_async(
    input_column_name="Job Description English", 
    output_column_name="Job Description Extracted",
    input_text_length=None,
    output_text_length=None,
    num_rows=None,  
    df=test.copy(), 
    system_prompt=system_prompt,
    user_prompt=user_prompt,
    gpt_model="gpt-4o-2024-11-20",
    client=client_async,
    batch_size=5,
    concurrency_limit=10,
    cache_file="../data/cache/job_description_extracted_cache_gpt-4o-2024-11-20.json"
)

df_extracted_test.head()
# Out:
# Processing Batches: 100%|██████████| 7/7 [00:01<00:00,  6.86it/s]
#            Location            Region  EU Member  Schengen Agreement  \
# 2089    Switzerland            Europe      False                True
# 2806  United States  Northern America      False               False
# 1146          Italy            Europe       True                True
# 1110          Italy            Europe       True                True
# 196          Canada  Northern America      False               False
#
#      Google Domain Type Google Domain Used  \
# 2089            default         google.com
# 2806            default         google.com
# 1146            default         google.com
# 1110            default         google.com
# 196             default         google.com
#
#                                               Job Title  \
# 2089                            Senior Mobile Developer
# 2806             Android Developer (Must speak Spanish)
# 1146  CyberConsulthink | Opportunità Mobile Develope...
# 1110  iOS Mobile Application Developer - Design and ...
# 196                                Senior iOS Developer
#
#                 Company Name                                     Job Location  \
# 2089  Nembrini Consulting SA                                              NaN
# 2806             Hire Orbitt                                         Anywhere
# 1146        CyberConsulthink  Ascoli Piceno, Province of Ascoli Piceno, Italy
# 1110             Eidos D.O.O                                            Italy
# 196             Konrad Group                                         Anywhere
#
#                                           Apply Options  ... Confidence  \
# 2089                                         Learn4Good  ...   0.999996
# 2806                                          Glassdoor  ...   0.999997
# 1146     CyberConsulthink | Azienda Informatica Hi-Tech  ...   0.999996
# 1110                                              BeBee  ...   0.999997
# 196   Jobgether, Glassdoor, Recruiter Jobs, Trabajo....  ...   0.999996
#
#                                 Job Description English  \
# 2089  Location: Sandhubel\r\nOn behalf of a major cl...
# 2806  Job Title: Android Developer (Must speak Spani...
# 1146  Join the CyberConsulthink team. We are looking...
# 1110  Are you a skilled iOS developer looking for a ...
# 196   This a Full Remote job, the offer is available...
#
#                                            Ground Truth Platform_GT  \
# 2089  1. Platform: Android\n2. Salary: Not mentioned...     Android
# 2806  1. Platform: iOS\n2. Salary: Not mentioned\n3....         iOS
# 1146  1. Platform: iOS\n2. Salary: €3,200 to €5,000\...         iOS
# 1110  1. Platform: Android\n2. Salary: Not mentioned...     Android
# 196   1. Platform: Android\n2. Salary: £40-50K plus ...     Android
#
#                   Salary_GT  \
# 2089          Not mentioned
# 2806          Not mentioned
# 1146       €3,200 to €5,000
# 1110          Not mentioned
# 196   £40-50K plus benefits
#
#                                         Requirements_GT  \
# 2089  - Minimum 3 years of commercial experience as ...
# 2806  - You can develop iOS applications at an inter...
# 1146  - 3 years of work experience with Swift\n  - B...
# 1110  - Deep expertise in Google CTS tests\n  - Stro...
# 196   - Degree in relevant subject\n  - Embedded rea...
#
#                                         Nice to have_GT  \
# 2089  - Familiarity with technologies and tools such...
# 2806  - Diving deep into lower-level libraries like ...
# 1146  - Experience in an environment where cybersecu...
# 1110  - Docker\n  - AUTOSAR (AUTomotive Open System ...
# 196   - Experience of Linux kernel and system progra...
#
#                                     Responsibilities_GT  \
# 2089  - Designing and implementing new screens in th...
# 2806  (list out or say "Not mentioned")\n  - Your wo...
# 1146  - Primarily focus on backend development for t...
# 1110  - Work inside an intercultural team of many la...
# 196                                       Not mentioned
#
#                                             Benefits_GT  \
# 2089  - Opportunity to participate in integration ev...
# 2806                                      Not mentioned
# 1146  - 28 vacation days + the option to purchase 10...
# 1110                                      Not mentioned
# 196   - An early finish on Fridays\n  - Bonus Privat...
#
#                               Job Description Extracted
# 2089  1. Platform: Android, iOS, Cross-platform  \n2...
# 2806  1. Platform: Android  \n2. Salary: $60 – 70 an...
# 1146  1. Platform: Android/iOS  \n2. Salary: Not men...
# 1110  1. Platform: iOS  \n2. Salary: $80,000-$120,00...
# 196   1. Platform: iOS  \n2. Salary: Not mentioned  ...
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Split Chat GPT's version into sections

# %%
df_extracted_test["Platform_GPT"] = df_extracted_test["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"1\. Platform"))
df_extracted_test["Salary_GPT"] = df_extracted_test["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"2\. Salary"))
df_extracted_test["Requirements_GPT"] = df_extracted_test["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"3\. Requirements"))
df_extracted_test["Nice to have_GPT"] = df_extracted_test["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"4\. Nice to have"))
df_extracted_test["Responsibilities_GPT"] = df_extracted_test["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"5\. Responsibilities"))
df_extracted_test["Benefits_GPT"] = df_extracted_test["Job Description Extracted"].apply(lambda x: tests_helpers.extract_section(x, r"6\. Benefits"))

df_extracted_test.head()
# Out:
#            Location            Region  EU Member  Schengen Agreement  \
# 2089    Switzerland            Europe      False                True
# 2806  United States  Northern America      False               False
# 1146          Italy            Europe       True                True
# 1110          Italy            Europe       True                True
# 196          Canada  Northern America      False               False
#
#      Google Domain Type Google Domain Used  \
# 2089            default         google.com
# 2806            default         google.com
# 1146            default         google.com
# 1110            default         google.com
# 196             default         google.com
#
#                                               Job Title  \
# 2089                            Senior Mobile Developer
# 2806             Android Developer (Must speak Spanish)
# 1146  CyberConsulthink | Opportunità Mobile Develope...
# 1110  iOS Mobile Application Developer - Design and ...
# 196                                Senior iOS Developer
#
#                 Company Name                                     Job Location  \
# 2089  Nembrini Consulting SA                                              NaN
# 2806             Hire Orbitt                                         Anywhere
# 1146        CyberConsulthink  Ascoli Piceno, Province of Ascoli Piceno, Italy
# 1110             Eidos D.O.O                                            Italy
# 196             Konrad Group                                         Anywhere
#
#                                           Apply Options  ...  \
# 2089                                         Learn4Good  ...
# 2806                                          Glassdoor  ...
# 1146     CyberConsulthink | Azienda Informatica Hi-Tech  ...
# 1110                                              BeBee  ...
# 196   Jobgether, Glassdoor, Recruiter Jobs, Trabajo....  ...
#
#                                         Nice to have_GT  \
# 2089  - Familiarity with technologies and tools such...
# 2806  - Diving deep into lower-level libraries like ...
# 1146  - Experience in an environment where cybersecu...
# 1110  - Docker\n  - AUTOSAR (AUTomotive Open System ...
# 196   - Experience of Linux kernel and system progra...
#
#                                     Responsibilities_GT  \
# 2089  - Designing and implementing new screens in th...
# 2806  (list out or say "Not mentioned")\n  - Your wo...
# 1146  - Primarily focus on backend development for t...
# 1110  - Work inside an intercultural team of many la...
# 196                                       Not mentioned
#
#                                             Benefits_GT  \
# 2089  - Opportunity to participate in integration ev...
# 2806                                      Not mentioned
# 1146  - 28 vacation days + the option to purchase 10...
# 1110                                      Not mentioned
# 196   - An early finish on Fridays\n  - Bonus Privat...
#
#                               Job Description Extracted  \
# 2089  1. Platform: Android, iOS, Cross-platform  \n2...
# 2806  1. Platform: Android  \n2. Salary: $60 – 70 an...
# 1146  1. Platform: Android/iOS  \n2. Salary: Not men...
# 1110  1. Platform: iOS  \n2. Salary: $80,000-$120,00...
# 196   1. Platform: iOS  \n2. Salary: Not mentioned  ...
#
#                       Platform_GPT  \
# 2089  Android, iOS, Cross-platform
# 2806                       Android
# 1146                   Android/iOS
# 1110                           iOS
# 196                            iOS
#
#                                              Salary_GPT  \
# 2089                                      Not mentioned
# 2806                                   $60 – 70 an hour
# 1146                                      Not mentioned
# 1110  $80,000-$120,000 per year, depending on your l...
# 196                                       Not mentioned
#
#                                        Requirements_GPT  \
# 2089  - Proven experience in developing mobile appli...
# 2806  · BS/MS degree in Computer Science, Engineerin...
# 1146                                      Not mentioned
# 1110  - **For Junior iOS Developers:**  \n     • Mus...
# 196   • 3+ years of professional experience in a sof...
#
#                                        Nice to have_GPT  \
# 2089                  - German and/or French is a plus.
# 2806  · iOS: 1 year (Preferred)  \n   · SDKs: 1 year...
# 1146                                      Not mentioned
# 1110  - **For Junior iOS Developers:**  \n     • Swi...
# 196   • Experience with or an understanding of newer...
#
#                                    Responsibilities_GPT  \
# 2089  - Proven experience in developing mobile appli...
# 2806  · Design and build applications for the Androi...
# 1146                                      Not mentioned
# 1110  • Developing and maintaining iOS mobile applic...
# 196   • Write maintainable, testable, and performant...
#
#                                            Benefits_GPT
# 2089  - Possibility of a permanent contract after a ...
# 2806                                 · Health insurance
# 1146                                      Not mentioned
# 1110  • A competitive salary based on your knowledge...
# 196   • Comprehensive Health & Wellness Benefits Pac...
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Calculate Fuzzy Scores
#
# 1. Token Sort Ratio (Handling Word Order Differences)<br>
# If two sentences contain the same words but in different order, Levenshtein distance alone might give a low similarity score. Instead, we:
# - Split both sentences into words.
# - Sort them alphabetically.
# - Recalculate Levenshtein Distance.
#
# 2. Token Set Ratio (Handling Partial Overlaps)<br>
# If one string is a subset of another, Token Set Ratio helps:
# - Convert both sentences into sets of unique words.
# - Compare only the common words.

# %%
tests_helpers.compare_fuzzy_sections(df_extracted_test)
# Out:
# Average Token Set Ratio per section:
# Platform: 49.9
# Salary: 64.26
# Requirements: 42.64
# Nice to have: 37.13
# Responsibilities: 38.7
# Benefits: 28.86
#
# Overall Average Token Set Ratio: 43.58
